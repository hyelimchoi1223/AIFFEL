# %% [markdown]
# # Unit 12 딕셔너리 사용하기
#
# 딕셔너리 : 연관된 값을 묶어서 저장

# %% [markdown]
# ## 12.1 딕셔너리 만들기

# %%
lux = {'health':490, 'mana':334, 'melee':550, 'armor':18.72}
lux
# Out:
# {'armor': 18.72, 'health': 490, 'mana': 334, 'melee': 550}

# %% [markdown]
# 키-값 쌍으로 지정해야 한다.

# %%
# 키 값이 중복되면
lux = {'health':490, 'mana':334, 'melee':550, 'armor':18.72, 'health':500}
lux['health'] # 뒤에 있는 값이 사용됨.
# Out:
# 500

# %%
lux # 앞에 490은 저장되지 않음.
# Out:
# {'armor': 18.72, 'health': 500, 'mana': 334, 'melee': 550}

# %%
# 자료형을 섞어서 사용할 수 있음
x={100:'hundred', False:0, 3.5:[1,2,3,4]}

# %%
x[100]
# Out:
# 'hundred'

# %%
x[False]
# Out:
# 0

# %%
x[3.5]
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# 단!! 키에는 딕셔너리와 리스트를 사용할 수 없다.

# %%
x = {[1,2,3]:'test'}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-5771e9124052> in <module>()
# ----> 1 x = {[1,2,3]:'test'}
#
# TypeError: unhashable type: 'list'

# %%
# 빈 딕셔너리 만들기
x = {}
y = dict()
print(x, y)
# Out:
# {} {}

# %%
# dict로 딕셔너리 만들기
# lux = {'health':490, 'mana':334, 'melee':550, 'armor':18.72}
lux= dict(health=490, mana=334, melee=550, armor=18.72)
lux
# Out:
# {'armor': 18.72, 'health': 490, 'mana': 334, 'melee': 550}

# %%
# zip 함수를 이용해 딕셔너리 만들기
lux2 = dict(zip(['health', 'mana', 'melee', 'armor'],[490, 334, 550, 18.72]))
lux2
# Out:
# {'armor': 18.72, 'health': 490, 'mana': 334, 'melee': 550}

# %%
# 튜플을 이용해 딕셔너리 만들기
# 리스트 안에 (키, 값) 튜플을 나열해서 만듬
lux3 = dict([('health', 490),('mana', 334),('melee', 550),('armor', 18.72)])
lux3
# Out:
# {'armor': 18.72, 'health': 490, 'mana': 334, 'melee': 550}

# %%
# dict 함수 안에 {}로 딕셔너리 생성
lux4=dict({'health':490, 'mana':334, 'melee':550, 'armor':18.72})
lux4
# Out:
# {'armor': 18.72, 'health': 490, 'mana': 334, 'melee': 550}

# %% [markdown]
# ## 12.2 딕셔너리의 키에 접근하고 값 할당하기
# 딕셔너리 키에 접근할 때는 딕셔너리 뒤에 [] 안에 키를 지정해주면 된다.

# %%
lux= dict(health=490, mana=334, melee=550, armor=18.72)

# %%
lux['health']
# Out:
# 490

# %%
# 딕셔너리 키에 값 할당하기
lux['health'] = 600
lux
# Out:
# {'armor': 18.72, 'health': 600, 'mana': 334, 'melee': 550}

# %%
# 없는 키를 할당하면 딕셔너리에 해당 키가 추가됨.
lux['attack_speed'] = 500
lux
# Out:
# {'armor': 18.72, 'attack_speed': 500, 'health': 600, 'mana': 334, 'melee': 550}

# %%
# 딕셔너리에 키가 있는지 없는지 확인
'mana' in lux
# Out:
# True

# %%
'speed' not in lux
# Out:
# True

# %%
# 딕셔너리의 키 개수 구하기
len(lux)
# Out:
# 5

# %% [markdown]
# ## 12.4 연습문제
# 게임 캐릭터의 체력(health)과 이동 속도(movement speed)가 출력되게 만드세요.

# %%
camille = {
    'health': 575.6,
    'health_regen': 1.7,
    'mana': 338.8,
    'mana_regen': 1.63,
    'melee': 125,
    'attack_damage': 60,
    'attack_speed': 0.625,
    'armor': 26,
    'magic_resistance': 32.1,
    'movement_speed': 340
}

print(camille['health'])
print(camille['movement_speed'])
# Out:
# 575.6
# 340

# %% [markdown]
# 표준 입력으로 문자열 여러 개와 숫자(실수) 여러 개가 두 줄로 입력됩니다. 입력된 첫 번째 줄은 키, 두 번째 줄은 값으로 하여 딕셔너리를 생성한 뒤 딕셔너리를 출력하는 프로그램을 만드세요. input().split()의 결과를 변수 한 개에 저장하면 리스트로 저장됩니다.

# %%
keys = input().split()
values = list(map(float, input().split()))
result = dict(zip(keys, values))
print(result)
# Out:
# {}

# %% [markdown]
# # 문자열 한 줄을 여러 줄로 입력하는 방법

# %%
s = 'Fortunately, however, for the reputation of Asteroid B-612, \
a Turkish dictator made a law that his subjects, under pain of death, \
should change to European costume. \
So in 1920 the astronomer gave his demonstration all over again, \
dressed with impressive style and elegance. \
And this time everybody accepted his report.'
print(s)
# Out:
# Fortunately, however, for the reputation of Asteroid B-612, a Turkish dictator made a law that his subjects, under pain of death, should change to European costume. So in 1920 the astronomer gave his demonstration all over again, dressed with impressive style and elegance. And this time everybody accepted his report.

# %% [markdown]
# # Unit 13 if 조건문
#
# 조건문은 특정 조건일 때 코드를 실행하는 문법

# %%
#if 조건식:
#  코드

# %%
x = 10
if x == 10:
    print('10입니다.')

# pep8 스타일 가이드에 따라 조건식 하위 실행할 코드 앞에는 들여쓰기 4칸을 해야함.
# Out:
# 10입니다.

# %% [markdown]
# 조건문의 실행 흐름을 그림으로 표현
# ![그림1.png](data:image/png;base64,...)

# %%
# if 조건문에서 코드 생략하기
x = 10
if x ==10:
    pass  # TODO: 해야할 일 입니다.

# %% [markdown]
# ## 13.2 if 조건문과 들여쓰기
# 조건문에서는 들여쓰기가 중요하다.

# %%
x = 10
if x==10:
    print(x)
      print('error')
# Out:
#   File "<ipython-input-27-713d4e5a5237>", line 4
#     print('error')
#     ^
# IndentationError: unexpected indent

# %%
x = 10
if x == 10:
    print(x)
    print(x+2)
# Out:
# 10
# 12

# %%
x = 10
if x != 10:
    print('is not ', x)
print(x)
# Out:
# 10

# %% [markdown]
# ## 13.3 중첩 if 조건문 사용하기

# %%
x = 15
if x >= 10:
    print('10 이상입니다.')
    if x  == 10:
        print('10입니다.')
    if x == 15:
        print('15입니다.')
    if x == 20:
        print('20입니다.')
# Out:
# 10 이상입니다.
# 15입니다.

# %% [markdown]
# ## 13.6 연습문제

# %%
x = 5
if x != 10:
    print('ok')
# Out:
# ok

# %% [markdown]
# 표준 입력으로 가격(정수)과 쿠폰 이름이 각 줄에 입력됩니다. Cash3000 쿠폰은 3,000원, Cash5000 쿠폰은 5,000원을 할인합니다. 쿠폰에 따라 할인된 가격을 출력하는 프로그램을 만드세요(input에서 안내 문자열은 출력하지 않아야 합니다).

# %%
price = int(input())
coupon_name = input()
if coupon_name == "Cash3000":
    price = price-3000
if coupon_name == "Cash5000":
    price = price-5000
print(price)
# Out:
# 27000
# Cash3000
# 24000

# %% [markdown]
# # Unit 14 else를 사용하여 두 방향으로 분기하기

# %%
# if 조건문:
#    코드 1
#else:
#    코드 2

# %%
x = 5
if x == 10:
    print('10입니다.')
else:
    print('10이 아닙니다.')
# Out:
# 10이 아닙니다.

# %% [markdown]
# if-else의 실행 흐름
# ![그림2.png](data:image/png;base64,...)

# %%
# 변수에 값 할당하는 것을 if, else로 축약하기
x = 5
if x==10:
    y = x
else:
    y = 0

y
# Out:
# 0

# %%
x = 5
y = x if x == 10 else 0
y
# Out:
# 0

# %% [markdown]
# ## 14.3 if 조건문의 동작 방식

# %%
if True:
    print('참')
else:
    print('거짓')

if False:
    print('참')
else:
    print('거짓')

if None:
    print('참')
else:
    print('거짓')
# Out:
# 참
# 거짓
# 거짓

# %% [markdown]
# None인 경우 거짓이다. 잘 기억해놔야함!!

# %%
if 0:
    print('참')
else:
    print('거짓') # 0은 거짓

if 1:
    print('참')
else:
    print('거짓')  

if 0x1F:
    print('참')
else:
    print('거짓')

if 0b1000:
    print('참')
else:
    print('거짓')

if 13.5:
    print('참')
else:
    print('거짓')
# Out:
# 거짓
# 참
# 참
# 참
# 참

# %%
if 'Hello':
    print('참')
else:
    print('거짓')

if '':
    print('참')
else:
    print('거짓')
# Out:
# 참
# 거짓

# %% [markdown]
# 값 자체가 있으면 참, 없으면 거짓
# 0, None, ''은 False
